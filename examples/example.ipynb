# %%
# !pwd
# Out:
# /Users/tekrajchhetri/Documents/brainypedia_codes_design/GrobidArticleExtractor/examples/examples

# %%
# %cd ..
# Out:
# /Users/tekrajchhetri/Documents/brainypedia_codes_design/GrobidArticleExtractor/examples

# %%
# %cd ..
# Out:
# /Users/tekrajchhetri/Documents/brainypedia_codes_design/GrobidArticleExtractor

# %%
# !pip uninstall GrobidArticleExtractor -y
# !pip install -e .
# Out:
# Found existing installation: GrobidArticleExtractor 0.0.1.dev1+e1ed9cf
# Uninstalling GrobidArticleExtractor-0.0.1.dev1+e1ed9cf:
#   Successfully uninstalled GrobidArticleExtractor-0.0.1.dev1+e1ed9cf
# Obtaining file:///Users/tekrajchhetri/Documents/brainypedia_codes_design/GrobidArticleExtractor
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: click<9.0.0,>=8.1.7 in /opt/anaconda3/lib/python3.11/site-packages (from GrobidArticleExtractor==0.0.1.dev7+dbc8ab0) (8.1.7)
# Requirement already satisfied: lxml<6.0.0,>=5.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from GrobidArticleExtractor==0.0.1.dev7+dbc8ab0) (5.3.0)
# Requirement already satisfied: pathlib<2.0.0,>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from GrobidArticleExtractor==0.0.1.dev7+dbc8ab0) (1.0.1)
# Requirement already satisfied: pytest<9.0.0,>=8.3.4 in /opt/anaconda3/lib/python3.11/site-packages (from GrobidArticleExtractor==0.0.1.dev7+dbc8ab0) (8.3.4)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /opt/anaconda3/lib/python3.11/site-packages (from GrobidArticleExtractor==0.0.1.dev7+dbc8ab0) (2.32.3)
# Requirement already satisfied: iniconfig in /opt/anaconda3/lib/python3.11/site-packages (from pytest<9.0.0,>=8.3.4->GrobidArticleExtractor==0.0.1.dev7+dbc8ab0) (1.1.1)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.11/site-packages (from pytest<9.0.0,>=8.3.4->GrobidArticleExtractor==0.0.1.dev7+dbc8ab0) (24.1)
# Requirement already satisfied: pluggy<2,>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from pytest<9.0.0,>=8.3.4->GrobidArticleExtractor==0.0.1.dev7+dbc8ab0) (1.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.3->GrobidArticleExtractor==0.0.1.dev7+dbc8ab0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.3->GrobidArticleExtractor==0.0.1.dev7+dbc8ab0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.3->GrobidArticleExtractor==0.0.1.dev7+dbc8ab0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.3->GrobidArticleExtractor==0.0.1.dev7+dbc8ab0) (2024.2.2)
# Building wheels for collected packages: GrobidArticleExtractor
#   Building editable for GrobidArticleExtractor (pyproject.toml) ... done
#   Created wheel for GrobidArticleExtractor: filename=grobidarticleextractor-0.0.1.dev7+dbc8ab0-py3-none-any.whl size=7035 sha256=dc5dbedae271c0952c07a77794ba70370a4ebb912fbb140a5154be5c89fc7b27
#   Stored in directory: /private/var/folders/sn/689s4rzd4694xvr4js9f9vz00000gn/T/pip-ephem-wheel-cache-mzsekfcp/wheels/f3/82/f9/39afe392e430b47ee2f93f2eba599e2235edb684efc1c0c5ac
# Successfully built GrobidArticleExtractor
# Installing collected packages: GrobidArticleExtractor
# Successfully installed GrobidArticleExtractor-0.0.1.dev7+dbc8ab0

# %%
# !pip show GrobidArticleExtractor
# Out:
# Name: GrobidArticleExtractor
# Version: 0.0.1.dev7+dbc8ab0
# Summary: GrobidArticleExtractor is a Python package designed to extract and organize content from scientific papers in PDF format.
# Home-page: https://github.com/sensein/GrobidArticleExtractor
# Author: tekrajchhetri
# Author-email: tekrajchhetri@gmail.com
# License: Apache-2.0
# Location: /opt/anaconda3/lib/python3.11/site-packages
# Editable project location: /Users/tekrajchhetri/Documents/brainypedia_codes_design/GrobidArticleExtractor
# Requires: click, lxml, pathlib, pytest, requests
# Required-by:

# %%
# !pip list | grep GrobidArticleExtractor
# Out:
# GrobidArticleExtractor                   0.0.1.dev7+dbc8ab0 /Users/tekrajchhetri/Documents/brainypedia_codes_design/GrobidArticleExtractor

# %%
from GrobidArticleExtractor import GrobidArticleExtractor

# %%
extractor = GrobidArticleExtractor()

# %%
# %cd /
# Out:
# CODE_OF_CONDUCT.md README.md          examples           pyproject.toml
# CONTRIBUTING.md    dist               grobid             src
# LICENSE.txt        docs_style         poetry.lock

# %%
xml_content = extractor.process_pdf("pdf_files/gpt-ner.pdf")

# %%
if xml_content:
    # Extract and organize content
    result = extractor.extract_content(xml_content)
    
    # Access metadata
    print(result['metadata'])
    
    # Access sections
    for section in result['sections']:
        print(section['heading'])
        if 'content' in section:
            print(section['content'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 if xml_content:
#       2     # Extract and organize content
#       3     result = extractor.extract_content(xml_content)
#       5     # Access metadata
#
# NameError: name 'xml_content' is not defined

# %%
#cli

# !pwd
# Out:
# /Users/tekrajchhetri/Desktop/grobid

# %%
# %cd ..
# Out:
# /Users/tekrajchhetri/Desktop

# %%
# !python cli.py examples/pdf_files -o cli_op
# Out:
# python: can't open file '/Users/tekrajchhetri/Desktop/cli.py': [Errno 2] No such file or directory

# %%
# !ls cli_op/
# Out:
# 2411.json    gpt-ner.json
